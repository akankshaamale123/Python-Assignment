# %%
import pandas as pd
import numpy as np

# %%
patient_df = pd.read_csv(r"E:\DATA sCIENCE\Data set\Patient_Data.csv")
patient_df
# Out:
#    PatientID     Name   Department     Doctor  BillAmount  ReceptionistID  \
# 0        101    Alice   Cardiology  Dr. Smith      5000.0               1
# 1        102      Bob    Neurology   Dr. John         NaN               2
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0               1
# 3        104    David   Cardiology  Dr. Smith      6200.0               3
# 4        105      Eva  Dermatology   Dr. Rose         NaN               2
# 5        101    Alice   Cardiology  Dr. Smith      5000.0               1
#
#         CheckInTime
# 0  2023-01-10 09:00
# 1  2023-01-11 10:30
# 2  2023-01-12 11:00
# 3  2023-01-13 12:00
# 4  2023-01-14 08:45
# 5  2023-01-10 09:00

# %%
patient_df.shape
# Out:
# (6, 7)

# %%
patient_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PatientID       6 non-null      int64
#  1   Name            6 non-null      object
#  2   Department      6 non-null      object
#  3   Doctor          6 non-null      object
#  4   BillAmount      4 non-null      float64
#  5   ReceptionistID  6 non-null      int64
#  6   CheckInTime     6 non-null      object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 468.0+ bytes

# %%
data = patient_df[['PatientID','Department','Doctor','BillAmount']]
print(data)
# Out:
#    PatientID   Department     Doctor  BillAmount
# 0        101   Cardiology  Dr. Smith      5000.0
# 1        102    Neurology   Dr. John         NaN
# 2        103  Orthopedics    Dr. Lee      7500.0
# 3        104   Cardiology  Dr. Smith      6200.0
# 4        105  Dermatology   Dr. Rose         NaN
# 5        101   Cardiology  Dr. Smith      5000.0

# %%
patient_df.drop(columns=['ReceptionistID','CheckInTime'], inplace=True)

# %%
patient_df
# Out:
#    PatientID     Name   Department     Doctor  BillAmount
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John         NaN
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose         NaN
# 5        101    Alice   Cardiology  Dr. Smith      5000.0

# %%
total_bill = patient_df.groupby('Department')['BillAmount'].sum().reset_index()
total_bill
# Out:
#     Department  BillAmount
# 0   Cardiology     16200.0
# 1  Dermatology         0.0
# 2    Neurology         0.0
# 3  Orthopedics      7500.0

# %%
patient_df.rename(columns = {'BillAmount':'total_bill'}, inplace = True)
patient_df
# Out:
#    PatientID     Name   Department     Doctor  total_bill
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John         NaN
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose         NaN
# 5        101    Alice   Cardiology  Dr. Smith      5000.0

# %%
patient_df.drop_duplicates(subset='PatientID', inplace=True)
patient_df
# Out:
#    PatientID     Name   Department     Doctor  total_bill
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John         NaN
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose         NaN

# %%
patient_df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
patient_df.isna()
# Out:
#    PatientID   Name  Department  Doctor  total_bill
# 0      False  False       False   False       False
# 1      False  False       False   False        True
# 2      False  False       False   False       False
# 3      False  False       False   False       False
# 4      False  False       False   False        True

# %%
patient_mean = patient_df['total_bill'].mean()
patient_mean
# Out:
# np.float64(6233.333333333333)

# %%
patient_df = patient_df.fillna(patient_mean)
patient_df
# Out:
#    PatientID     Name   Department     Doctor   total_bill
# 0        101    Alice   Cardiology  Dr. Smith  5000.000000
# 1        102      Bob    Neurology   Dr. John  6233.333333
# 2        103  Charlie  Orthopedics    Dr. Lee  7500.000000
# 3        104    David   Cardiology  Dr. Smith  6200.000000
# 4        105      Eva  Dermatology   Dr. Rose  6233.333333

# %%
billing_data = pd.read_csv(r"E:\DATA sCIENCE\Data set\Billing_Data.csv")
billing_data
# Out:
#    PatientID  InsuranceCovered  FinalAmount
# 0        101              2000         3000
# 1        102              1500         3500
# 2        103              2500         5000
# 3        104              3000         3200
# 4        105              1000         4000

# %%
merge_df = pd.merge(patient_df,billing_data, on = 'PatientID', how = 'inner')
merge_df
# Out:
#    PatientID     Name   Department     Doctor   total_bill  InsuranceCovered  \
# 0        101    Alice   Cardiology  Dr. Smith  5000.000000              2000
# 1        102      Bob    Neurology   Dr. John  6233.333333              1500
# 2        103  Charlie  Orthopedics    Dr. Lee  7500.000000              2500
# 3        104    David   Cardiology  Dr. Smith  6200.000000              3000
# 4        105      Eva  Dermatology   Dr. Rose  6233.333333              1000
#
#    FinalAmount
# 0         3000
# 1         3500
# 2         5000
# 3         3200
# 4         4000

# %%
new_patients = pd.DataFrame({
    'PatientID':[201,202],
    'Name' : ['Jermaya','Concad'],
    'Department': [' Cardiology','Orthopedics'],
    'Doctor' : ['Dr.Amale','Dr.Lee'],
    'total_bill': [67885.565,567.34]
})
new_data = pd.concat([patient_df, new_patients], ignore_index=True)
new_data
# Out:
#    PatientID     Name   Department     Doctor    total_bill
# 0        101    Alice   Cardiology  Dr. Smith   5000.000000
# 1        102      Bob    Neurology   Dr. John   6233.333333
# 2        103  Charlie  Orthopedics    Dr. Lee   7500.000000
# 3        104    David   Cardiology  Dr. Smith   6200.000000
# 4        105      Eva  Dermatology   Dr. Rose   6233.333333
# 5        201  Jermaya   Cardiology   Dr.Amale  67885.565000
# 6        202   Concad  Orthopedics     Dr.Lee    567.340000

# %%
new_columns = pd.DataFrame({
    'InsuranceCovered' :[ True , False, True, False, True,True,False],
    'FinalAmount' : [433221,43212,909876,5432,7654,234567,4567]
})
new_data = pd.concat([new_data,new_columns], axis = 1)
new_data
# Out:
#    PatientID     Name   Department     Doctor    total_bill  InsuranceCovered  \
# 0        101    Alice   Cardiology  Dr. Smith   5000.000000              True
# 1        102      Bob    Neurology   Dr. John   6233.333333             False
# 2        103  Charlie  Orthopedics    Dr. Lee   7500.000000              True
# 3        104    David   Cardiology  Dr. Smith   6200.000000             False
# 4        105      Eva  Dermatology   Dr. Rose   6233.333333              True
# 5        201  Jermaya   Cardiology   Dr.Amale  67885.565000              True
# 6        202   Concad  Orthopedics     Dr.Lee    567.340000             False
#
#    FinalAmount
# 0       433221
# 1        43212
# 2       909876
# 3         5432
# 4         7654
# 5       234567
# 6         4567
