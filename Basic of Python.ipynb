# %%
# Exercise1 : check the number is prime or not

num = int(input("Enter the number"))
if num <= 1:
    print(num, "is not a prime number")
else:
    for i in range(2, int(num**0.5) +1):
        if num % 2 == 0:
            print(num, "is not a prime number")
            break
    else:
        print(num, "is a prime number")
# Out:
# Enter the number 88
# 88 is not a prime number

# %%
# Exercise2 : Product of Random Numbers

import random 
num1 = random.randint(1,10)
num2 = random.randint(1,10)
print(f"The product of the {num1} and {num2}")
user_answer = int(input("Enter the product of the number"))
correct_answer = num1*num2
if correct_answer == user_answer:
    print("Correct!")
else:
    print(f"Wrong!, The correct answer is {correct_answer}")
# Out:
# The product of the 5 and 4
# Enter the product of the number 8
# Wrong!, The correct answer is 20

# %%
# Exercise3 : Square of Even/odd numbers

for i in range(100,201):
    if i%2==0 :
        print("Even No is :")
        print(f"{i}^2 = {i**2}")
    elif i%2 != 0 :
        print("Odd No is :")
        print(f"{i}^2 = {i**2}")
# Out:
# Even No is :
# 100^2 = 10000
# Odd No is :
# 101^2 = 10201
# Even No is :
# 102^2 = 10404
# Odd No is :
# 103^2 = 10609
# Even No is :
# 104^2 = 10816
# Odd No is :
# 105^2 = 11025
# Even No is :
# 106^2 = 11236
# Odd No is :
# 107^2 = 11449
# Even No is :
# 108^2 = 11664
# Odd No is :
# 109^2 = 11881
# Even No is :
# 110^2 = 12100
# Odd No is :
# 111^2 = 12321
# Even No is :
# 112^2 = 12544
# Odd No is :
# 113^2 = 12769
# Even No is :
# 114^2 = 12996
# Odd No is :
# 115^2 = 13225
# Even No is :
# 116^2 = 13456
# Odd No is :
# 117^2 = 13689
# Even No is :
# 118^2 = 13924
# Odd No is :
# 119^2 = 14161
# Even No is :
# 120^2 = 14400
# Odd No is :
# 121^2 = 14641
# Even No is :
# 122^2 = 14884
# Odd No is :
# 123^2 = 15129
# Even No is :
# 124^2 = 15376
# Odd No is :
# 125^2 = 15625
# Even No is :
# 126^2 = 15876
# Odd No is :
# 127^2 = 16129
# Even No is :
# 128^2 = 16384
# Odd No is :
# 129^2 = 16641
# Even No is :
# 130^2 = 16900
# Odd No is :
# 131^2 = 17161
# Even No is :
# ...

# %%
# Exercise4 : Hospital Billing System

charges = {
    "charges_per_day" : 2000 * 4,
    "Doctor_fess" : 1500,
    "medicine_charge" : 2400,
    "lab_test" : 300*3
}
total_before_discount = 0
for items, cost in charges.items():
    print(f"{items}: ₹{cost}")
    total_before_discount+=cost

if total_before_discount > 10000:
    discount = 0.1*total_before_discount
else:
    0
final_bill = total_before_discount - discount

print("total before discount=₹",total_before_discount )
print("Discount=₹",discount)
print("Final bill=₹",final_bill)
# Out:
# charges_per_day: ₹8000
# Doctor_fess: ₹1500
# medicine_charge: ₹2400
# lab_test: ₹900
# total before discount=₹ 12800
# Discount=₹ 1280.0
# Final bill=₹ 11520.0
